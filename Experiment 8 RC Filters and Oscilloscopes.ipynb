# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
low_pass_gain = [1.00, 0.836, 0.80, 0.646, 0.600, 0.500, 0.476, 0.450, 0.375, 0.350]
low_pass_freq = [18.868, 38.462, 55.556, 76.923, 90.909, 100.00, 142.857, 166.667, 166.667, 200.00]
plt.plot(low_pass_freq, low_pass_gain, marker="o", linestyle="solid")
plt.title("Gain, Av versus calculated frequency, f")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Gain Av (volts)")
plt.show()

plt.savefig('low_pass_filter_graph.png')

# %%
high_pass_gain = [0.233, 0.472, 0.620, 0.756, 0.778, 0.974, 1.00, 1.083, 1.114, 1.114]
high_pass_freq = [18.519, 38.462, 55.556, 71.429, 90.909, 125.00, 125.00, 142.857, 142.857, 142.857]
plt.plot(high_pass_freq, high_pass_gain, marker="o", linestyle="solid")
plt.title("Gain, Av versus calculated frequency, f")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Gain Av (volts)")
plt.show()

plt.savefig('high_pass_filter_graph.png')
