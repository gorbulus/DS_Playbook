# %% [markdown]
# # Matplotlib Techniques

# %% [markdown]
# "I believe that visualization is  one of he most powerful means of achieving goals."
# -Harvey McKay

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

#add ad title
plt.title("Nominal GDP")

# add a lahel to the y-axis
plt.ylabel("Billions of $")

# show the plot

plt.show()

# %%
# Bar chart
movies = ["Star Wars", "Mrs. Doubtfire", "Pulp Fiction", "Aliens", "Goodfellas"]
num_oscars = [5, 11, 3, 8, 10]

# %%
#plot bars with left x-coordinates [0, 1, 2, 3, 4], heights [num_oscars]
# add a label and y-axis label
plt.title("My favorite movies")
plt.ylabel("Number of Oscars")

#label x-axis with movie names at bar centers
plt.xticks(range(len(movies)), movies)

plt.bar(range(len(movies)), num_oscars)
plt.show()

# %% [markdown]
# # Word cloud

# %%
data = [ ("big data", 100, 15), 
         ("Hadoop", 95, 25), 
         ("Python", 75, 50), 
         ("R", 50, 40), 
         ("Machine learning", 80, 20), 
         ("Statistics", 20, 60), 
         ("Data Science", 60, 70), 
         ("Analytics", 90, 3), 
         ("Team player", 85, 85), 
         ("Dynamic", 2, 90), 
         ("Synergies", 70, 1), 
         ("Actionable insights", 40, 30), 
         ("Think outside the box", 45, 10), 
         ("Self-starter", 30, 50), 
         ("Customer focus", 65, 15), 
         ("Thought leadership", 35, 35)]

# %%
def text_size(total: int) -> float:
    """ equals 8 if total is 0, 28 if total is 200"""
    return 8 + total / 200 * 20

for word, job_popularity, resume_popularity in data:
    plt.text(job_popularity, resume_popularity, word, ha="center", va="center", size=text_size(job_popularity + resume_popularity))
    
# labels and axis formatting
plt.xlabel("Popularity on Job Postings")
plt.ylabel("Popularity on Resumes")
plt.axis([0, 100, 0, 100])
plt.xticks([])
plt.yticks([])

plt.show()

# %%
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
totals = [226.3, 198.7, 197.6, 155.7, 145.8, 177.8, 151.05, 150.8, 175.5, 175.5, 175.5, 175.5]

# %%
plt.plot(months, totals, marker='o', linestyle='solid')
plt.title("Monthly quote volume")
plt.ylabel("Project volume (in millions)")
plt.xlabel("2020 Months")
# Todo - fix this, make the x-labels rotated 45 degrees and anchored to the tick mark
plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode="anchor")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fb5eade319af> in <module>
#       4 plt.xlabel("2020 Months")
#       5 # Todo - fix this, make the x-labels rotated 45 degrees and anchored to the tick mark
# ----> 6 plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode="anchor")
#       7
#       8 plt.show()
#
# NameError: name 'ax' is not defined

# %%
# plotting histograms of bucketed numeric values
# import Counter module
from collections import Counter

# %%
# data
grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

# create buckets of grades by decile, but put a 100 in with the 90s as an "A"
histogram = Counter(min(grade // 10 * 10, 90) for grade in grades)

# %%
# creating the plot

#shift bars right by 5, give each bar its correct height, give each bar a width of 10, black edges for each bar
plt.bar([x + 5 for x in histogram.keys()], histogram.values(), 10, edgecolor=(0, 0, 0))

# x-axis from -5 to 105, y-axis from 0 to 5
plt.axis([-5, 105, 0, 5])

# x-axis labels at 10, 20, 30.... etc
plt.xticks([10 * i for i in range(11)])

# axis labels and title
plt.xlabel("Decile")
plt.ylabel("Number of students")
plt.title("Distribution of exam grades")

# show the plot
plt.show()

# %% [markdown]
# # Line charts

# %% [markdown]
# Line plots are great for showing trends in data, whereas bar charts are better at showing categorical data.

# %%
# plot example showing several line charts with a legend
# data
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

# %%
# mutiple plots can be called to plt.plot in a single chart to show multiple series
plt.plot(xs, variance, "g-", label = "variance") # green solid line
plt.plot(xs, bias_squared, "r-.", label = "bias^2") # red dot-dashed line
plt.plot(xs, total_error, "b:", label = "total error") # blue dotted line

# create a legend from the labels assigned to each series
# loc=9 means "top center" orientation on the legend
plt.legend(loc=9)
plt.xlabel("Model complexity")
plt.xticks([])
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %% [markdown]
# # Scatterplots

# %% [markdown]
# Scatter plots are great for visualizing the relationship between two paired sets of data.

# %%
# data
# number of 'friends' each user has, and number of minutes spent on platform each day
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67] 
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

# %%
# scatterplot
plt.scatter(friends, minutes)

# %%
#  add labels for each point
for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label, xy=(friend_count, minute_count), xytext=(5, -5), textcoords='offset points')

# %%
plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("Number of friends")
plt.ylabel("Daily mins online")
plt.show()

# %% [markdown]
# # Data + Science, not Data Science yet

# %% [markdown]
# A wave in an oscillatory motion that propagates through space with some velocity, v.  A simple way to create a wave on a stretched string is to displace one end vertically up and down.  This displacement of the end of the string is transferred to the neighboring fibers in the string, thus creating a traveling wave.  Such a wave is transverse because the up and down mostion of the bibers is perpendicular or transverseto the direction of teh wave as it travels down the length of the string.  When the oscillatory motino of the wave is parallel to the direction of propagation the wave is longitudinal.  Sound is a longitudinal wave.
#
# ## Experiment
# A suspended string was weighed and measured in length before being attached to an oscillator device.  The string was measured for level height at both ends of suspension so the effects of gravity was non-existent in the creation of antinodes.  The length of the string was measured in both relaxed and suspended states and duly noted in the data collection.  The goal of the experiment is to calculate the relationship between string tension and antinode development in the suspended string.  I believe that as the tension increases, the antinodes will decrease in development because the fixed variable is the length of the string.  The variable is the tension.  Similar to the guitar string, as the length is "pinched off" or shortened by depressing the string to the fretboard, the pitch of the note increases accordingly.  With guitar there are special places on the fretboard that one can create octive harmonics that represent certain divisions in ratio to the length of the string. #JimiHendrixPhysics

# %% [markdown]
# ## Data
# Data collected:

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
def getStringData(mass, length, massDensity, susLength):
    stringData = []
    stringData = [mass, length, massDensity, susLength]
    return stringData

# %%
myString = getStringData(3.9, 487, .008, 463)
print(myString)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-324d7c7b72bc> in <module>
# ----> 1 myString = getStringData(3.9, 487, .008, 463)
#       2 print(myString)
#
# NameError: name 'getStringData' is not defined

# %%
def getStandingWaveData(hangMass, tension, antinodes, wavelength, logR, logN):
    standingWaveData = []
    standingWaveData = [hangMass, tension, antinodes, wavelength, logR, logN]
    return standingWaveData

# %%
myStandingWave = getStandingWaveData(155, 1.52, 6.2, 25, .576, 12)
print(myStandingWave)

# %%
tension = [1.52, 1.62, 1.81, 1.91]
antinodes = [25, 24, 23, 22]
plt.plot(antinodes, tension, marker="o", linestyle="solid")
plt.title("String tension effect on antinodes")
plt.xlabel("Number of Antinodes n")
plt.ylabel("String tension (dynes)")
plt.show()

plt.savefig('tension_to_node.png')

# %%
logt = [5.18, 5.21, 5.26, 5.28]
logn = [1.39, 1.38, 1.36, 1.34]
plt.plot(logn, logt, marker="o", linestyle="solid")
plt.title("Log(t) in relation to Log(n)")
plt.xlabel("Log(n)")
plt.ylabel("Log(T)")
plt.show()

plt.savefig('log_graph.png')

# %%
g = sns.jointplot(x=antinodes, y=tension,
                  kind="reg", truncate=False,
                  xlim=(0, 40), ylim=(0, 3),
                  color="b", height=7)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# Fixing random state for reproducibility
np.random.seed(19680801)

# %%
N_points = 100000
n_bins = 20

# Generate a normal distribution, center at x=0 and y=5
x = np.random.randn(N_points)
y = .4 * x + np.random.randn(100000) + 5

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)

# We can set the number of bins with the `bins` kwarg
axs[0].hist(x, bins=n_bins)
axs[1].hist(y, bins=n_bins)

# %%
fig, axs = plt.subplots(1, 2, tight_layout=True)

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = axs[0].hist(x, bins=n_bins)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

# We can also normalize our inputs by the total number of counts
axs[1].hist(x, bins=n_bins, density=True)

# Now we format the y-axis to display percentage
axs[1].yaxis.set_major_formatter(PercentFormatter(xmax=1))

# %%
fig, ax = plt.subplots(tight_layout=True)
hist = ax.hist2d(x, y)

# %%
fig, axs = plt.subplots(3, 1, figsize=(5, 15), sharex=True, sharey=True,
                        tight_layout=True)

# We can increase the number of bins on each axis
axs[0].hist2d(x, y, bins=40)

# As well as define normalization of the colors
axs[1].hist2d(x, y, bins=40, norm=colors.LogNorm())

# We can also define custom numbers of bins for each axis
axs[2].hist2d(x, y, bins=(80, 10), norm=colors.LogNorm())

plt.show()
